# %% [markdown]
# # 2. Simple Accuracy Test

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.autograd as ag
import time
import h5py

import sys
sys.path.append('../../Utilities/')
from pytorch_complex import *
from utility import *

sys.path.append('../../Models2/')
from fpm import *

sys.path.append('../../Denoisers/')
from pytorch_proximal import *

sys.path.append('../../Reconstruction/')
from recon import *


import sigpy.plot as pl

dtype = torch.float32
np_dtype = np.float32

mul_c  = ComplexMul().apply
div_c  = ComplexDiv().apply
abs_c = ComplexAbs().apply

# %%
# setup GPU
gpu_device = 0
torch.cuda.set_device(gpu_device)
device = torch.device("cuda:"+str(gpu_device) if torch.cuda.is_available() else "cpu")
torch.cuda.get_device_properties(gpu_device)
# Out:
# _CudaDeviceProperties(name='TITAN Xp', major=6, minor=1, total_memory=12196MB, multi_processor_count=30)

# %% [markdown]
# ## Load data

# %%
with h5py.File('/mikRAID/dataset_train_full.h5', 'r') as f:
    imgs = np.array(f['imgs'])
    maps = np.array(f['maps'])
    masks = np.array(f['masks'])
    
data_idx = 1
imgs = imgs[data_idx,...]
maps = maps[data_idx,...]
masks = masks[data_idx,...]
print(imgs.shape, maps.shape, masks.shape)
# Out:
# (256, 232) (12, 256, 232) (256, 232)

# %% [markdown]
# ## Transform into torch variables

# %%
imgs_t = torch.stack((torch.from_numpy(imgs.real),torch.from_numpy(imgs.imag)),2)
maps_t = torch.stack((torch.from_numpy(maps.real),torch.from_numpy(maps.imag)),3)

# under sampling
# masks_t = torch.stack((torch.from_numpy(masks),torch.from_numpy(masks)),2)

# fully sampled
masks_t = torch.ones_like(imgs_t)

Np = imgs_t.shape[0:2]
print(imgs_t.shape, maps_t.shape, masks_t.shape)
print(Np)
# Out:
# torch.Size([256, 232, 2]) torch.Size([12, 256, 232, 2]) torch.Size([256, 232, 2])
# torch.Size([256, 232])

# %% [markdown]
# ## Setup Model

# %%
from mri import *
alpha = torch.tensor([1e-1],device=device).type(dtype)
grad = MRI(Np,imgs_t,maps_t,masks_t,alpha,noise_level=0,device=device).to(device)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-20-c725353cac7e> in <module>
#       1 from mri import *
#       2 alpha = torch.tensor([1e-1],device=device).type(dtype)
# ----> 3 grad = MRI(Np,imgs_t,maps_t,masks_t,alpha,noise_level=0,device=device).to(device)
#
# ~/Workspace/PYTHON/Pytorch_Physics_Library/Models2/mri.py in __init__(self, Np, img, maps, sampling, alpha, noise_level, T, testFlag, device)
#      35         self.y = self.model(img,device=device)
#      36         self.noise = torch.randn_like(self.y).to(device)
# ---> 37         self.y += self.noise * noise_level
#      38         self.y = self.y.to(device)
#      39
#
# RuntimeError: expected type torch.FloatTensor but got torch.cuda.FloatTensor

# %% [markdown]
# ## Verify: Forward Backward Accuracy Check

# %%
x = torch.randn_like(imgs_t).to(device)
forward = grad.forward(imgs_t,device=device)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-19-92b6c820feb2> in <module>
#       1 x = torch.randn_like(imgs_t).to(device)
# ----> 2 forward = grad.forward(imgs_t,device=device)
#
# ~/Workspace/PYTHON/Pytorch_Physics_Library/Models2/mri.py in forward(self, x, device)
#      45
#      46     def forward(self, x, device='cpu'):
# ---> 47         return x + self.step(x)
#      48
#      49     def inverse(self, x, device='cpu'):
#
# ~/Workspace/PYTHON/Pytorch_Physics_Library/Models2/mri.py in step(self, x)
#      63
#      64     def step(self,x):
# ---> 65         return -1 * self.alpha * self.grad(x)
#      66
#      67     def grad(self,x,device='cpu'):
#
# RuntimeError: expected type torch.cuda.FloatTensor but got torch.FloatTensor

# %%
coil_idx = 4
plt.figure()
plt.imshow(getAbs(torch.ifft(grad.y[coil_idx,...],2)).numpy())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# test gradient
output = grad.grad(torch.zeros_like(imgs_t))
# output = grad.grad(imgs_t)
print(output.shape)
# Out:
# torch.Size([256, 232, 2])

# %%
M = torch.sum(getAbs(maps_t),dim=0).numpy()

plt.figure()
plt.imshow(getAbs(output).numpy())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.imshow(masks)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Setup iterative reconstruction network

# %%
testFlag = True

from mri import *
alpha = torch.tensor([1e-1],device=device).type(dtype)
grad = MRI(Np,imgs_t.to(device),maps_t.to(device),masks_t.to(device),alpha,noise_level=0,device=device,testFlag=testFlag)
grad.to(device)

# setup proximal model
from pytorch_proximal import *
thr = torch.tensor([1e-2],device=device).type(dtype)
alpha = torch.tensor([1e-4],device=device).type(dtype)
prox = AbsWaveletSoftThr(Np,thr,alpha,testFlag=testFlag,device=device)
prox.to(device)

pgd = PGD(grad,prox)
N = 100
network = genNetwork(pgd,N)
# Out:
# [autoreload of pytorch_proximal failed: Traceback (most recent call last):
#   File "/home/kellman/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/kellman/anaconda3/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 376, in superreload
#     module = reload(module)
#   File "/home/kellman/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/home/kellman/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 724, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 860, in get_code
#   File "<frozen importlib._bootstrap_external>", line 791, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "../../Denoisers/pytorch_proximal.py", line 123
#     def inverse(self,x,device='cpu'):
#       ^
# SyntaxError: invalid syntax
# ]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-134-b2969620fe1e> in <module>
#      10 thr = torch.tensor([1e-2],device=device).type(dtype)
#      11 alpha = torch.tensor([1e-4],device=device).type(dtype)
# ---> 12 prox = AbsWaveletSoftThr(Np,thr,alpha,testFlag=testFlag,device=device)
#      13 prox.to(device)
#      14
#
# NameError: name 'AbsWaveletSoftThr' is not defined

# %%
x0 = torch.zeros_like(imgs_t).to(device)
xN,X = feedforward(network,x0,interFlag=True,testFlag=True,device=device)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-129-69d823254a35> in <module>
#       1 x0 = torch.zeros_like(imgs_t).to(device)
# ----> 2 xN,X = feedforward(network,x0,interFlag=True,testFlag=True,device=device)
#
# ~/Workspace/PYTHON/Pytorch_Physics_Library/Reconstruction/recon.py in feedforward(network, x0, iterFunc, interFlag, testFlag, device)
#      32
#      33         for layer in network[ii]:
# ---> 34             x = layer.forward(x,device=device)
#      35
#      36
#
# ~/Workspace/PYTHON/Pytorch_Physics_Library/Denoisers/pytorch_proximal.py in forward(self, x, shiftx, shifty, device)
#      34         a = self.trans.forward(x,shiftx,shifty,device=self.device)
#      35         a_s = [a[0],self.prox(a[1]),self.prox(a[2]),self.prox(a[3])]
# ---> 36         x = self.trans.adjoint(a_s,shiftx,shifty,device=self.device)
#      37         return x
#      38
#
# ~/Workspace/PYTHON/Pytorch_Physics_Library/Denoisers/pytorch_transforms.py in adjoint(self, a, shiftx, shifty, device)
#      38     def adjoint(self,a,shiftx=False,shifty=False,device='cpu'): # inverse
#      39         x = torch.zeros(self.Np,dtype=dtype,device=device)
# ---> 40         x[0::2,0::2] = self.c*(a[0] + a[1] + a[2] + a[3])
#      41         x[0::2,1::2] = self.c*(a[0] + a[1] - a[2] - a[3])
#      42         x[1::2,0::2] = self.c*(a[0] - a[1] + a[2] - a[3])
#
# RuntimeError: expand(torch.cuda.FloatTensor{[128, 116, 2]}, size=[128, 116]): the number of sizes provided (2) must be greater or equal to the number of dimensions in the tensor (3)
